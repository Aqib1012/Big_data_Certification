# %%
#Some imp function in pandas 

import pandas as pd

readfile=pd.read_csv("titanic_data.csv")

# %%
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
readfile.isnull() ## To show about null values
readfile.isnull().sum()

readfile.head() # this will show first 5 records but we can give parameter to show specific 
readfile.tail() ## this will show last 5 records but we can give parameter to show specific
readfile.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib.pyplot as plt ### Both Libraries To show graphically data in vs code
import seaborn as sns # Hum yahi use krain gay matplotlib is lia import ki ha k won seaborn ko support krta

sns.set()
# %matplotlib inline

# %%
sns.countplot(x='Sex',data=readfile)  # this is use to craete a bar chart of a single entity (x,y)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Survived',data=readfile)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Pclass',data=readfile)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x="Sex",hue="Survived",data=readfile,color='red') # hue is used for merge
# Out:
# C:\Users\aqibr\AppData\Local\Temp\ipykernel_13836\3403036006.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.countplot(x="Sex",hue="Survived",data=readfile,color='red') # hue is used for merge
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x="Pclass",hue="Sex",data=readfile)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x="Survived",hue="Pclass",data=readfile)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Pclass",hue="Survived",data=readfile)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.catplot(x="Sex",hue="Survived", col="Pclass",data=readfile) #Col parameter will divided in no of graph
