# %% [markdown]
# ####### Loops

# %%
#forloop 
#for a in range(10):
   # print(a)
    #if(a==5):
       # break
    
#print(a)  #this will print the last value of loop

#in range funtion we can give staring and ending value also first parameter is starting point second is ending and we can give 3rd also which will specify gap between values

#for i in range(4,10):
   # print(i)

#for j in range(0,20,2):
 #   print(j)

#name="aqib walayat"

#for char in name:
    #print(char)

#While loop 

#count=0

#while count<10:
   # print(count)
    #count=count+1


for i in range(10):
    if i==5:
     break
    print(i)

for z in range(10):
  if z%2==0:
   continue
  print(z)
  
      
for i in range(3):
  for j in range(2):
    print(f"",{i},"",{j})  

n=10
sum=0

for i in range(11):
  sum=sum+i
  print(sum)
# Out:
# 0
# 1
# 2
# 3
# 4
# 1
# 3
# 5
# 7
# 9
#  {0}  {0}
#  {0}  {1}
#  {1}  {0}
#  {1}  {1}
#  {2}  {0}
#  {2}  {1}
# 0
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
#prime numbers example    its a number which can not multiple of anyother number

for i in range (1,101):
    if i>1:
        for j in range(2,i):
            if i%j ==0:
                break
            else:
                print(i)
# Out:
# 3
# 5
# 5
# 5
# 7
# 7
# 7
# 7
# 7
# 9
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 15
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 21
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 25
# 25
# 25
# 27
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 33
# 35
# 35
# 35
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 39
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# ...

# %% [markdown]
# ####### Topics that wil discuss in tomorow class
# ####### List{},set(),dictioanry{}
